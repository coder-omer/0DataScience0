# %% [markdown]
# <a href="https://colab.research.google.com/github/coder-omer/0DataScience0/blob/main/seaborn_preclass2_scatterplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn: scatterplot

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
diamonds = sns.load_dataset('diamonds')

diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds = diamonds[
            diamonds.cut.isin(['Premium', 'Good']) & 
            diamonds.color.isin(['D', 'F', 'J'])
            ].sample(n=100, random_state=22)

diamonds.shape
# Out:
# (100, 10)

# %%
diamonds.cut.value_counts()
# Out:
# Premium      69
# Good         31
# Ideal         0
# Very Good     0
# Fair          0
# Name: cut, dtype: int64

# %%
diamonds.dropna()
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 21628   1.26  Premium     D     VS2   62.5   59.0   9720  6.91  6.85  4.30
# 7302    1.20  Premium     D     SI2   60.2   60.0   4203  6.94  6.81  4.14
# 50019   0.70  Premium     F     SI1   62.1   59.0   2196  5.68  5.72  3.54
# 26898   1.54  Premium     D     VS2   59.3   59.0  16889  7.61  7.54  4.49
# 2794    1.00     Good     F     SI2   59.4   64.0   3259  6.52  6.48  3.86
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 19116   1.01  Premium     F    VVS1   62.5   58.0   7882  6.41  6.35  3.99
# 4517    1.00     Good     D     SI2   64.0   59.0   3634  6.29  6.24  4.01
# 39943   0.28     Good     F    VVS2   64.9   57.0    492  4.13  4.16  2.69
# 35535   0.34  Premium     F     VS1   60.0   59.0    905  4.59  4.55  2.74
# 46240   0.53  Premium     F     VS2   61.9   58.0   1753  5.20  5.17  3.21
#
# [100 rows x 10 columns]

# %%
diamonds.cut.value_counts()
# Out:
# Premium      69
# Good         31
# Ideal         0
# Very Good     0
# Fair          0
# Name: cut, dtype: int64

# %% [markdown]
# ## Intro Visuals

# %%
import pandas as pd
import numpy as np

# %%
sns.set_style('white')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
blue, orange, green, red = sns.color_palette()[:4]

# %%
pts_x = [1] #, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1] #, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic1.svg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pts_x = [1, 2] #, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3] #, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic2.svg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pts_x = [1, 2, 1.5] #, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5] #, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic3.svg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5] #, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2] #, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic4.svg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5] #, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4] #, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic5.svg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasicFull.svg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
for x,y in zip(pts_x, pts_y):
    print((x, y))
# Out:
# (1, 1)
# (2, 3)
# (1.5, 2.5)
# (4, 3)
# (3, 3.5)
# (2.5, 2)
# (2.1, 2.5)
# (1.5, 1.8)
# (3.5, 4)
# (1, 1.3)
# (2.6, 3.2)
# (3.4, 3)
# (1.3, 2)
# (0.5, 1)

# %%
cat = [0, 0, 1, 1, 0, 0, 1, 0, 1, 1, 0, 0, 1, 1]

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=200, hue=cat, alpha=0.7, edgecolor='black', palette={0: 'xkcd:crimson', 1: '#3d9f98'})
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byHue.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=200, style=cat, alpha=0.7, edgecolor='black', color='xkcd:crimson')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byStyle.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, size=cat, alpha=0.7, edgecolor='black', color='xkcd:crimson', sizes=[50, 300])
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_bySize.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, size=cat, hue=cat, style=cat,
                alpha=0.7, edgecolor='black',  
                sizes=[100, 300],
                palette={0: 'xkcd:crimson', 1: '#3d9f98'}
               )
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byAll.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('dark')

# %%
sns.scatterplot(diamonds.carat, diamonds.price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(x='carat', y='price', data=diamonds);

# %%
sns.scatterplot(x='x', y='y', data=diamonds);

# %% [markdown]
# ## Semantic Variables

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ### hue

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds
               );

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds,
                palette = ['purple', '#55CCCC'],
                hue_order=['Good', 'Premium']
               );

# %% [markdown]
# #### Continuous Variable

# %%
sns.scatterplot(x='carat', y='price', hue='depth',
                data=diamonds
               );

# %% [markdown]
# ### style

# %%
sns.scatterplot(x='carat', y='price', style='cut',
                data=diamonds,
                s=100
               );

# %% [markdown]
# ### size

# %%
sns.scatterplot(x='carat', y='price', size='cut',
                data=diamonds
               );

# %%
sns.scatterplot(x='carat', y='price', size='cut',
                data=diamonds, 
                sizes=[150, 50]
               );
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-19717dc9e8c2> in <module>()
#       1 sns.scatterplot(x='carat', y='price', size='cut',
#       2                 data=diamonds,
# ----> 3                 sizes=[150, 50]
#       4                );
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     814
#     815     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# --> 816     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#     817     p.map_style(markers=markers, order=style_order)
#     818
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py in map(cls, plotter, *args, **kwargs)
#      51         # This method is assigned the __init__ docstring
#      52         method_name = "_{}_map".format(cls.__name__[:-7].lower())
# ---> 53         setattr(plotter, method_name, cls(plotter, *args, **kwargs))
#      54         return plotter
#      55
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py in __init__(self, plotter, sizes, order, norm)
#     294
#     295                 levels, lookup_table = self.categorical_mapping(
# --> 296                     data, sizes, order,
#     297                 )
#     298                 size_range = None
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py in categorical_mapping(self, data, sizes, order)
#     357             if len(sizes) != len(levels):
#     358                 err = "The `sizes` list has the wrong number of values."
# --> 359                 raise ValueError(err)
#     360
#     361             lookup_table = dict(zip(levels, sizes))
#
# ValueError: The `sizes` list has the wrong number of values.

# %%
sns.scatterplot(x='carat', y='price', size='depth',
                data=diamonds
               );

# %% [markdown]
# ### hue + style + size

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='cut',
                data=diamonds,
                s=100
               );

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='color',
                data=diamonds,
                s=100
               );

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='color',
                size='depth',
                data=diamonds);

# %% [markdown]
# ## Additional Styling

# %% [markdown]
# ### alpha

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds,
                s=100,
                alpha=0.6
               );

# %% [markdown]
# ### marker styling
#
# Check the [matplotlib scatter](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html) and the [marker style docs](https://matplotlib.org/api/_as_gen/matplotlib.markers.MarkerStyle.html#matplotlib.markers.MarkerStyle) for more styling of the markers themselves

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds, 
                s=200,
                marker='*'
               );

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds, 
                s=200, 
                marker='*',
                edgecolor='black'
               );
